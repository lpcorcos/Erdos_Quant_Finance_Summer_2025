# %% [markdown]
# # Paper Trading and Delta-Hedging in Action
#
# **2025 Introduction to Quantiative Methods in Finance**
#
# **The Erdös Institute**

# %% [markdown]
# ### Paper Trading
#
# In this notebook we will create a mock trading portfolio that includes option trades and regular intervals of delta hedging using Black-Scholes formulas.
#
#
#
# #### Portfolio Parameters:
#
# **Initial Capital and Portfolio Value**: \$400,000
#
#
#
# **Portfolio Objective**:
#
# 1) Sell call options several different stocks that expire Friday June 20, 2025 at 4:00pm EST.
#
# 2) Hedge at regular intervals to protect premiums received.
#
# 3) Set aside capital in a money-market account for hedging.
#
#
#
# **Capital Availability**
#
# 1) Unused capital will be kept in a money-market account earning a risk-free interest rate of 3.5%.
#
# 2) We allocate 400,000 for option trading and hedging. To keep capital available to hedge sold options, we leave
# $$\mbox{premium} + .4*(\mbox{spot price})\times \Delta$$
# amount of capital per sold option.
#
#
# **Parameters For Black-Scholes Delta-Hedging**
# The volatility of stock will be computed by finding the volatility of the stock over the previous one-month trading period.
#
#
# **Hedging Process**:
#
# Hedging will take place daily. Times of hedges, spot prices, etc... will be continuously updated in this notebook.

# %% [markdown]
# ## Trades on Thursday June 12, 2025 at approxiamtely 2:30pm EST
#
# ### Sold AAPL calls
#
#
# **Spot Price**: $199
#
# **Strike Price**: $200
#
# **Options Sold**: 1000
#
# **Premium**: $2.68
#
# **Sigma** 0.20131039589216015
#
# **Delta**: 0.4465619359954549
#
#
# ### AAPL Hedge
#
# **AAPL Shares Purchased**: 447
#
# **Capital Spent**: $88,953
#
#
#
#
# ### Sold QQQ calls
#
#
# **Spot Price**: $533.55
#
# **Strike Price**: $540
#
# **Options Sold**: 300
#
# **Premium**: $2.38
#
# **Sigma**: 0.128855
#
# **Delta**: 0.4776422182484017
#
#
# ### QQQ Hedge
#
# **QQQ Shares Purchased**: 143
#
# **Capital Spent**: $76,297.65
#
#
#
#
# ### Sold TSLA calls
#
#
# **Spot Price**: $319.30
#
# **Strike Price**: $307.50
#
# **Options Sold**: 100
#
# **Premium**: $17.80
#
# **sigma**: 0.7280307359884242
#
# **Delta**: .9857054121729372
#
#
# ### TSLA Hedge
#
# **TSLA Shares Purchased**: 100
#
# **Capital Spent**: $31,930
#
#
# ## Capital and Stock Values:
#
# **Premiums**: $5,174
#
# **Initial Capital Remaining**: $202,819.35
#
# **Total Capital**: $207,993.35
#
# **Stock Value**: $197,180.65

# %% [markdown]
# ## Trades on Friday June 13, 2025 at 2:00PM EST
#
# ### AAPL Hedge
#
# **AAPL Shares Previously owned**: 447
#
# **New AAPL Spot Price**: $197.64
#
# **New AAPL Delta**: .5146113703139118
#
# **Adjusted Stock Amount**: 343
#
# **Sold Shares of Stock**: 104
#
# **Capital Received**: $20,554.56
#
#
# ###QQQ Hedge
#
# **QQQ Shares Previously owned**: 143
#
# **New QQQ Spot Price**: $530.58
#
# **New QQQ Delta**: 0.1638906296628045
#
# **Adjusted Stock Amount**: 49
#
# **Sold Shares of Stock**: 94
#
# **Capital Received**: $49,912.12
#
#
# ###TSLA Hedge
#
# **TSLA Shares Previously owned**: 100
#
# **New TSLA Spot Price**: $332.35
#
# **New TSLA Delta**: 0.8036951749467047
#
# **Adjusted Stock Amount**: 81
#
# **Sold Shares of Stock**: 19
#
# **Capital Received**: $6,314.65
#
#
# ### Capital
#
# **Interest earned on capital**: $19.95
#
# **New Capital Amount**: $284,794.63
#
#
# ### Stock
#
# **Current Stock Value**: $120,709.29

# %% [markdown]
# ## Trades on Monday June 16, 2025 at 1:30PM EST
#
# ### AAPL Hedge
#
# **AAPL Shares Previously owned**: 343
#
# **New AAPL Spot Price**: $198
#
# **New AAPL Delta**: 0.3375538566233761
#
# **Adjusted Stock Amount**: 338
#
# **Sold Shares of Stock**: 5
#
# **Capital Received**: $990
#
#
# ###QQQ Hedge
#
# **QQQ Shares Previously owned**: 49
#
# **New QQQ Spot Price**: $535
#
# **New QQQ Delta**: 0.2699822861628899
#
# **Adjusted Stock Amount**: 81
#
# **Bought Shares of Stock**: 32
#
# **Capital Spent**: $17,120
#
#
# ###TSLA Hedge
#
# **TSLA Shares Previously owned**: 81
#
# **New TSLA Spot Price**: $329.47
#
# **New TSLA Delta**: 0.8157944524563803
#
# **Adjusted Stock Amount**: 82
#
# **Bought Shares of Stock**: 1
#
# **Capital Spent**: $329.47
#
#
# ### Capital
#
# **Interest earned on capital**: $81.94
#
# **New Capital Amount**: $268,417.10
#
#
# ### Stock
#
# **Current Stock Value**: $137,275.54

# %% [markdown]
# ## Trades on Tuesday June 17, 2025 at 1:30PM EST
#
# ### AAPL Hedge
#
# **AAPL Shares Previously owned**: 338
#
# **New AAPL Spot Price**: $195.62
#
# **New AAPL Delta**: 0.11733821577890896
#
# **Adjusted Stock Amount**: 117
#
# **Sold Shares of Stock**: 221
#
# **Capital Received**: $43,232.02
#
#
# ### QQQ Hedge
#
# **QQQ Shares Previously owned**: 81
#
# **New QQQ Spot Price**: $528.95
#
# **New QQQ Delta**: 0.040984207202111975
#
# **Adjusted Stock Amount**: 12
#
# **Sold Shares of Stock**: 69
#
# **Capital Received**: $36,497.55
#
#
# ### TSLA Hedge
#
# **TSLA Shares Previously owned**: 82
#
# **New TSLA Spot Price**: $315.98
#
# **New TSLA Delta**: 0.6734718186102451
#
# **Adjusted Stock Amount**: 67
#
# **Sold Shares of Stock**: 15
#
# **Capital Received**: $4,739.70
#
#
# ### Capital
#
# **Interest earned on capital**: $25.74
#
# **New Capital Amount**: $352,912.11
#
#
# ### Stock
#
# **Current Stock Value**: $50,405.60

# %% [markdown]
# ## Trades on Wednesday June 18, 2025 at 10:00AM EST
#
# ### AAPL Hedge
#
# **AAPL Shares Previously owned**: 117
#
# **New AAPL Spot Price**: $196.29
#
# **New AAPL Delta**: 0.10819259828374245
#
# **Adjusted Stock Amount**: 108
#
# **Sold Shares of Stock**: 9
#
# **Capital Received**: $1,766.61
#
#
# ### QQQ Hedge
#
# **QQQ Shares Previously owned**: 12
#
# **New QQQ Spot Price**: $529.96
#
# **New QQQ Delta**: 0.026024113755672124
#
# **Adjusted Stock Amount**: 8
#
# **Sold Shares of Stock**: 4
#
# **Capital Received**: $2119.84
#
#
# ### TSLA Hedge
#
# **TSLA Shares Previously owned**: 67
#
# **New TSLA Spot Price**: $322.92
#
# **New TSLA Delta**: 0.8259895648497874
#
# **Adjusted Stock Amount**: 83
#
# **Bought Shares of Stock**: 16
#
# **Capital Spent**: $5,166.72
#
#
# ### Capital
#
# **Interest earned on capital**: $33.84
#
# **New Capital Amount**: $351,665.68
#
#
# ### Stock
#
# **Current Stock Value**: $52,241.36

# %%
aapl_spot = 196.29
qqq_spot = 529.96
tsla_spot = 322.92

aapl_strike = 200
qqq_strike = 540
tsla_strike = 307.50

aapl_delta = 0.10819259828374245
qqq_delta = 0.026024113755672124
tsla_delta = 0.8259895648497874

aapl_strike = 200
qqq_strike = 540
tsla_strike = 307.50

aapl_sigma = 0.20131039589216015
qqq_sigma = 0.128855
tsla_sigma = 0.7280307359884242

aapl_options = 1000
qqq_options = 300
tsla_options = 100

t = (datetime.datetime.strptime('2025-06-20-14-30', '%Y-%m-%d-%H-%M') - \
datetime.datetime.strptime('2025-06-18-14-30', '%Y-%m-%d-%H-%M')).total_seconds()/(60*60*24*365)

r = .035

# %%
#Package Import
import numpy as np
import pandas as pd
import yfinance as yf
import datetime
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import norm
from scipy.stats import shapiro
import scipy.stats as stats
sns.set_style('darkgrid')

# %%
#Import functions associated with Black-Scholes Equations

# %run functions_black_scholes.py
